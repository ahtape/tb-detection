# %%
from tb_detect import predict_tb
import os
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

input_dir = "../test_data"
files = [f for f in os.listdir(input_dir)]
for i, file in enumerate(files):
    img_path = os.path.join(input_dir, file)
    result = predict_tb(img_path)
    print(f"Image: {file}, Prediction: {result}")
# Out:
# Image: Normal-1000.png, Prediction: {'image': '../test_data/Normal-1000.png', 'probability_TB': 1.755805370694763e-12, 'probability_Normal': 0.9999999999982442, 'clinical_groups': {'Upper_lung_abnormality': 0.9999999999920044, 'Lower_lung_abnormality': 1.0, 'Left_right_asymmetry': 0.5311316291532046, 'Global_texture_score': 1.0}, 'explanation': 'Model sangat yakin bahwa paru dalam kondisi normal tanpa indikasi TB.'}
# Image: Normal-1001.png, Prediction: {'image': '../test_data/Normal-1001.png', 'probability_TB': 1.2986426202484832e-12, 'probability_Normal': 0.9999999999987014, 'clinical_groups': {'Upper_lung_abnormality': 1.0, 'Lower_lung_abnormality': 1.0, 'Left_right_asymmetry': 0.5160878186090726, 'Global_texture_score': 1.0}, 'explanation': 'Model sangat yakin bahwa paru dalam kondisi normal tanpa indikasi TB.'}
# Image: Normal-1003.png, Prediction: {'image': '../test_data/Normal-1003.png', 'probability_TB': 1.109478577395556e-08, 'probability_Normal': 0.9999999889052142, 'clinical_groups': {'Upper_lung_abnormality': 0.9000664739676891, 'Lower_lung_abnormality': 0.8781694481028268, 'Left_right_asymmetry': 0.5163702967031187, 'Global_texture_score': 1.0}, 'explanation': 'Model sangat yakin bahwa paru dalam kondisi normal tanpa indikasi TB.'}
# Image: Normal-1002.png, Prediction: {'image': '../test_data/Normal-1002.png', 'probability_TB': 1.305733838655325e-10, 'probability_Normal': 0.9999999998694267, 'clinical_groups': {'Upper_lung_abnormality': 0.9674790283763619, 'Lower_lung_abnormality': 0.9999999905224107, 'Left_right_asymmetry': 0.5613672048052372, 'Global_texture_score': 1.0}, 'explanation': 'Model sangat yakin bahwa paru dalam kondisi normal tanpa indikasi TB.'}
# Image: Normal-10.png, Prediction: {'image': '../test_data/Normal-10.png', 'probability_TB': 5.4697335670431026e-11, 'probability_Normal': 0.9999999999453026, 'clinical_groups': {'Upper_lung_abnormality': 0.9999999999873606, 'Lower_lung_abnormality': 0.9999999990802757, 'Left_right_asymmetry': 0.5216028971884735, 'Global_texture_score': 1.0}, 'explanation': 'Model sangat yakin bahwa paru dalam kondisi normal tanpa indikasi TB.'}
# Image: Normal-1004.png, Prediction: {'image': '../test_data/Normal-1004.png', 'probability_TB': 1.1997906587636105e-13, 'probability_Normal': 0.99999999999988, 'clinical_groups': {'Upper_lung_abnormality': 0.9813707363037677, 'Lower_lung_abnormality': 0.9996454764968267, 'Left_right_asymmetry': 0.5227056368172557, 'Global_texture_score': 1.0}, 'explanation': 'Model sangat yakin bahwa paru dalam kondisi normal tanpa indikasi TB.'}
# Image: Normal-100.png, Prediction: {'image': '../test_data/Normal-100.png', 'probability_TB': 1.0037977696950376e-05, 'probability_Normal': 0.9999899620223031, 'clinical_groups': {'Upper_lung_abnormality': 0.9467786928189885, 'Lower_lung_abnormality': 0.8451448964700061, 'Left_right_asymmetry': 0.6907683998730982, 'Global_texture_score': 1.0}, 'explanation': 'Model sangat yakin bahwa paru dalam kondisi normal tanpa indikasi TB.'}
# Image: Tuberculosis-1.png, Prediction: {'image': '../test_data/Tuberculosis-1.png', 'probability_TB': 0.9421051346689419, 'probability_Normal': 0.05789486533105814, 'clinical_groups': {'Upper_lung_abnormality': 0.9999999999908102, 'Lower_lung_abnormality': 0.9999999997770206, 'Left_right_asymmetry': 0.5434126337066411, 'Global_texture_score': 1.0}, 'explanation': 'Dominant coarse texture pada upper lobe mengarah ke TB post-primary.'}
# Image: Tuberculosis-10.png, Prediction: {'image': '../test_data/Tuberculosis-10.png', 'probability_TB': 0.9999999721248135, 'probability_Normal': 2.7875186492387627e-08, 'clinical_groups': {'Upper_lung_abnormality': 0.993781517229086, 'Lower_lung_abnormality': 0.11068439219059689, 'Left_right_asymmetry': 0.504200306942891, 'Global_texture_score': 0.9999999999695217}, 'explanation': 'Dominant coarse texture pada upper lobe mengarah ke TB post-primary.'}
# Image: Normal-1.png, Prediction: {'image': '../test_data/Normal-1.png', 'probability_TB': 2.461785551395731e-07, 'probability_Normal': 0.9999997538214449, 'clinical_groups': {'Upper_lung_abnormality': 0.9999999788286107, 'Lower_lung_abnormality': 0.9679616195851942, 'Left_right_asymmetry': 0.5944978008954335, 'Global_texture_score': 1.0}, 'explanation': 'Model sangat yakin bahwa paru dalam kondisi normal tanpa indikasi TB.'}
# Image: Tuberculosis-105.png, Prediction: {'image': '../test_data/Tuberculosis-105.png', 'probability_TB': 0.9999993257064171, 'probability_Normal': 6.742935828585317e-07, 'clinical_groups': {'Upper_lung_abnormality': 1.0, 'Lower_lung_abnormality': 1.0, 'Left_right_asymmetry': 0.5010887956287292, 'Global_texture_score': 1.0}, 'explanation': 'Dominant coarse texture pada upper lobe mengarah ke TB post-primary.'}
# Image: Tuberculosis-104.png, Prediction: {'image': '../test_data/Tuberculosis-104.png', 'probability_TB': 0.9999832858055768, 'probability_Normal': 1.6714194423173012e-05, 'clinical_groups': {'Upper_lung_abnormality': 1.0, 'Lower_lung_abnormality': 1.0, 'Left_right_asymmetry': 0.5054654648366638, 'Global_texture_score': 1.0}, 'explanation': 'Dominant coarse texture pada upper lobe mengarah ke TB post-primary.'}
# Image: Tuberculosis-100.png, Prediction: {'image': '../test_data/Tuberculosis-100.png', 'probability_TB': 0.9999575926618166, 'probability_Normal': 4.240733818339226e-05, 'clinical_groups': {'Upper_lung_abnormality': 1.0, 'Lower_lung_abnormality': 1.0, 'Left_right_asymmetry': 0.5081039972233807, 'Global_texture_score': 1.0}, 'explanation': 'Dominant coarse texture pada upper lobe mengarah ke TB post-primary.'}
# Image: Tuberculosis-101.png, Prediction: {'image': '../test_data/Tuberculosis-101.png', 'probability_TB': 0.9973740208184334, 'probability_Normal': 0.0026259791815665956, 'clinical_groups': {'Upper_lung_abnormality': 0.9999812765724956, 'Lower_lung_abnormality': 0.9999860269894948, 'Left_right_asymmetry': 0.5059166181601307, 'Global_texture_score': 1.0}, 'explanation': 'Dominant coarse texture pada upper lobe mengarah ke TB post-primary.'}
# Image: Tuberculosis-103.png, Prediction: {'image': '../test_data/Tuberculosis-103.png', 'probability_TB': 0.9999390212433027, 'probability_Normal': 6.0978756697305236e-05, 'clinical_groups': {'Upper_lung_abnormality': 1.0, 'Lower_lung_abnormality': 1.0, 'Left_right_asymmetry': 0.5009688907820845, 'Global_texture_score': 1.0}, 'explanation': 'Dominant coarse texture pada upper lobe mengarah ke TB post-primary.'}
# Image: Tuberculosis-102.png, Prediction: {'image': '../test_data/Tuberculosis-102.png', 'probability_TB': 0.6396407836117874, 'probability_Normal': 0.36035921638821256, 'clinical_groups': {'Upper_lung_abnormality': 0.8185000700609104, 'Lower_lung_abnormality': 0.9996976407161521, 'Left_right_asymmetry': 0.5482674285485706, 'Global_texture_score': 1.0}, 'explanation': 'Dominant coarse texture pada upper lobe mengarah ke TB post-primary.'}

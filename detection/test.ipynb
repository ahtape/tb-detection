# %%
from tb_detect import predict_tb
import os
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

input_dir = "../test_data"
files = [f for f in os.listdir(input_dir)]
for i, file in enumerate(files):
    img_path = os.path.join(input_dir, file)
    result = predict_tb(img_path)
    print(f"Image: {file}, Prediction: {result}")
# Out:
# Image: Normal-1000.png, Prediction: {'image': '../test_data/Normal-1000.png', 'probability_TB': 1.755805370694763e-12, 'probability_Normal': 0.9999999999982442, 'clinical_groups': {'Upper_zone_opacity_score': 0.9618731586181396, 'Lower_zone_consolidation_score': 0.016010671927100276, 'Miliary_texture_score': 0.8829529022552469, 'Left_right_asymmetry_score': 0.8523197167779862}, 'explanation': 'Model sangat yakin bahwa paru dalam kondisi normal tanpa indikasi tuberkulosis.', 'heatmap_path': '/Users/ahtape/Documents/UGM/CS/semester 3/PCD/TB/tb-detection/detection/temp_mask/Normal-1000_overlay.png'}
# Image: Normal-1001.png, Prediction: {'image': '../test_data/Normal-1001.png', 'probability_TB': 1.2986426202484832e-12, 'probability_Normal': 0.9999999999987014, 'clinical_groups': {'Upper_zone_opacity_score': 0.029561283755221227, 'Lower_zone_consolidation_score': 0.9403431711850205, 'Miliary_texture_score': 0.941333465779357, 'Left_right_asymmetry_score': 0.9551741175579911}, 'explanation': 'Model sangat yakin bahwa paru dalam kondisi normal tanpa indikasi tuberkulosis.', 'heatmap_path': '/Users/ahtape/Documents/UGM/CS/semester 3/PCD/TB/tb-detection/detection/temp_mask/Normal-1001_overlay.png'}
# Image: Normal-1003.png, Prediction: {'image': '../test_data/Normal-1003.png', 'probability_TB': 1.109478577395556e-08, 'probability_Normal': 0.9999999889052142, 'clinical_groups': {'Upper_zone_opacity_score': 0.00816257115315989, 'Lower_zone_consolidation_score': 0.9918374288468401, 'Miliary_texture_score': 0.9542379822884609, 'Left_right_asymmetry_score': 0.6109099361353607}, 'explanation': 'Model sangat yakin bahwa paru dalam kondisi normal tanpa indikasi tuberkulosis.', 'heatmap_path': '/Users/ahtape/Documents/UGM/CS/semester 3/PCD/TB/tb-detection/detection/temp_mask/Normal-1003_overlay.png'}
# Image: Normal-1002.png, Prediction: {'image': '../test_data/Normal-1002.png', 'probability_TB': 1.305733838655325e-10, 'probability_Normal': 0.9999999998694267, 'clinical_groups': {'Upper_zone_opacity_score': 0.964811032015205, 'Lower_zone_consolidation_score': 0.06454330709694446, 'Miliary_texture_score': 0.6992595331934903, 'Left_right_asymmetry_score': 0.7925820633775986}, 'explanation': 'Model sangat yakin bahwa paru dalam kondisi normal tanpa indikasi tuberkulosis.', 'heatmap_path': '/Users/ahtape/Documents/UGM/CS/semester 3/PCD/TB/tb-detection/detection/temp_mask/Normal-1002_overlay.png'}
# Image: Normal-10.png, Prediction: {'image': '../test_data/Normal-10.png', 'probability_TB': 5.4697335670431026e-11, 'probability_Normal': 0.9999999999453026, 'clinical_groups': {'Upper_zone_opacity_score': 0.9839677794298057, 'Lower_zone_consolidation_score': 0.00816257115315989, 'Miliary_texture_score': 0.9418128698261607, 'Left_right_asymmetry_score': 0.7908583551670184}, 'explanation': 'Model sangat yakin bahwa paru dalam kondisi normal tanpa indikasi tuberkulosis.', 'heatmap_path': '/Users/ahtape/Documents/UGM/CS/semester 3/PCD/TB/tb-detection/detection/temp_mask/Normal-10_overlay.png'}
# Image: Normal-1004.png, Prediction: {'image': '../test_data/Normal-1004.png', 'probability_TB': 1.1997906587636105e-13, 'probability_Normal': 0.99999999999988, 'clinical_groups': {'Upper_zone_opacity_score': 0.025028838132706416, 'Lower_zone_consolidation_score': 0.986468468384193, 'Miliary_texture_score': 0.694402184503185, 'Left_right_asymmetry_score': 0.9784654632280743}, 'explanation': 'Model sangat yakin bahwa paru dalam kondisi normal tanpa indikasi tuberkulosis.', 'heatmap_path': '/Users/ahtape/Documents/UGM/CS/semester 3/PCD/TB/tb-detection/detection/temp_mask/Normal-1004_overlay.png'}
# Image: Normal-100.png, Prediction: {'image': '../test_data/Normal-100.png', 'probability_TB': 1.0037977696950376e-05, 'probability_Normal': 0.9999899620223031, 'clinical_groups': {'Upper_zone_opacity_score': 0.023715693891775788, 'Lower_zone_consolidation_score': 0.9135741054655231, 'Miliary_texture_score': 0.9234675655591036, 'Left_right_asymmetry_score': 0.9740321251904029}, 'explanation': 'Model sangat yakin bahwa paru dalam kondisi normal tanpa indikasi tuberkulosis.', 'heatmap_path': '/Users/ahtape/Documents/UGM/CS/semester 3/PCD/TB/tb-detection/detection/temp_mask/Normal-100_overlay.png'}
# Image: Tuberculosis-1.png, Prediction: {'image': '../test_data/Tuberculosis-1.png', 'probability_TB': 0.9421051346689419, 'probability_Normal': 0.05789486533105814, 'clinical_groups': {'Upper_zone_opacity_score': 0.008822974280156567, 'Lower_zone_consolidation_score': 0.9814852632297416, 'Miliary_texture_score': 0.9645823654416028, 'Left_right_asymmetry_score': 0.8302316752834438}, 'explanation': 'Pola konsolidasi pada zona bawah paru dapat mengarah ke TB primer atau infeksi bakteri lainnya.', 'heatmap_path': '/Users/ahtape/Documents/UGM/CS/semester 3/PCD/TB/tb-detection/detection/temp_mask/Tuberculosis-1_overlay.png'}
# Image: Tuberculosis-10.png, Prediction: {'image': '../test_data/Tuberculosis-10.png', 'probability_TB': 0.9999999721248135, 'probability_Normal': 2.7875186492387627e-08, 'clinical_groups': {'Upper_zone_opacity_score': 0.9918374288468401, 'Lower_zone_consolidation_score': 0.00816257115315989, 'Miliary_texture_score': 0.5786735865180432, 'Left_right_asymmetry_score': 0.6276478749427669}, 'explanation': 'Terdapat peningkatan opasitas dan tekstur kasar pada zona atas paru, konsisten dengan TB post-primary.', 'heatmap_path': '/Users/ahtape/Documents/UGM/CS/semester 3/PCD/TB/tb-detection/detection/temp_mask/Tuberculosis-10_overlay.png'}
# Image: Normal-1.png, Prediction: {'image': '../test_data/Normal-1.png', 'probability_TB': 2.461785551395731e-07, 'probability_Normal': 0.9999997538214449, 'clinical_groups': {'Upper_zone_opacity_score': 0.7775118993206601, 'Lower_zone_consolidation_score': 0.17915306435593265, 'Miliary_texture_score': 0.6036503301357051, 'Left_right_asymmetry_score': 0.990254244192947}, 'explanation': 'Model sangat yakin bahwa paru dalam kondisi normal tanpa indikasi tuberkulosis.', 'heatmap_path': '/Users/ahtape/Documents/UGM/CS/semester 3/PCD/TB/tb-detection/detection/temp_mask/Normal-1_overlay.png'}
# Image: Tuberculosis-105.png, Prediction: {'image': '../test_data/Tuberculosis-105.png', 'probability_TB': 0.9999993257064171, 'probability_Normal': 6.742935828585317e-07, 'clinical_groups': {'Upper_zone_opacity_score': 0.00816257115315989, 'Lower_zone_consolidation_score': 0.9898441550128314, 'Miliary_texture_score': 0.9171572536910866, 'Left_right_asymmetry_score': 0.736776274492528}, 'explanation': 'Pola konsolidasi pada zona bawah paru dapat mengarah ke TB primer atau infeksi bakteri lainnya.', 'heatmap_path': '/Users/ahtape/Documents/UGM/CS/semester 3/PCD/TB/tb-detection/detection/temp_mask/Tuberculosis-105_overlay.png'}
# Image: Tuberculosis-104.png, Prediction: {'image': '../test_data/Tuberculosis-104.png', 'probability_TB': 0.9999832858055768, 'probability_Normal': 1.6714194423173012e-05, 'clinical_groups': {'Upper_zone_opacity_score': 0.9833630921202259, 'Lower_zone_consolidation_score': 0.008413962270432339, 'Miliary_texture_score': 0.9199480731845469, 'Left_right_asymmetry_score': 0.8533827250342683}, 'explanation': 'Terdapat peningkatan opasitas dan tekstur kasar pada zona atas paru, konsisten dengan TB post-primary.', 'heatmap_path': '/Users/ahtape/Documents/UGM/CS/semester 3/PCD/TB/tb-detection/detection/temp_mask/Tuberculosis-104_overlay.png'}
# Image: Tuberculosis-100.png, Prediction: {'image': '../test_data/Tuberculosis-100.png', 'probability_TB': 0.9999575926618166, 'probability_Normal': 4.240733818339226e-05, 'clinical_groups': {'Upper_zone_opacity_score': 0.9591335819660641, 'Lower_zone_consolidation_score': 0.01099416259283468, 'Miliary_texture_score': 0.9540348385176314, 'Left_right_asymmetry_score': 0.9363969466449429}, 'explanation': 'Terdapat peningkatan opasitas dan tekstur kasar pada zona atas paru, konsisten dengan TB post-primary.', 'heatmap_path': '/Users/ahtape/Documents/UGM/CS/semester 3/PCD/TB/tb-detection/detection/temp_mask/Tuberculosis-100_overlay.png'}
# Image: Tuberculosis-101.png, Prediction: {'image': '../test_data/Tuberculosis-101.png', 'probability_TB': 0.9973740208184334, 'probability_Normal': 0.0026259791815665956, 'clinical_groups': {'Upper_zone_opacity_score': 0.9784421360951926, 'Lower_zone_consolidation_score': 0.00816257115315989, 'Miliary_texture_score': 0.9328268210138543, 'Left_right_asymmetry_score': 0.801118984068016}, 'explanation': 'Terdapat peningkatan opasitas dan tekstur kasar pada zona atas paru, konsisten dengan TB post-primary.', 'heatmap_path': '/Users/ahtape/Documents/UGM/CS/semester 3/PCD/TB/tb-detection/detection/temp_mask/Tuberculosis-101_overlay.png'}
# Image: Tuberculosis-103.png, Prediction: {'image': '../test_data/Tuberculosis-103.png', 'probability_TB': 0.9999390212433027, 'probability_Normal': 6.0978756697305236e-05, 'clinical_groups': {'Upper_zone_opacity_score': 0.00816257115315989, 'Lower_zone_consolidation_score': 0.9846991398052533, 'Miliary_texture_score': 0.9260339314220194, 'Left_right_asymmetry_score': 0.6341089232027963}, 'explanation': 'Pola konsolidasi pada zona bawah paru dapat mengarah ke TB primer atau infeksi bakteri lainnya.', 'heatmap_path': '/Users/ahtape/Documents/UGM/CS/semester 3/PCD/TB/tb-detection/detection/temp_mask/Tuberculosis-103_overlay.png'}
# Image: Tuberculosis-102.png, Prediction: {'image': '../test_data/Tuberculosis-102.png', 'probability_TB': 0.6396407836117874, 'probability_Normal': 0.36035921638821256, 'clinical_groups': {'Upper_zone_opacity_score': 0.9083255080345898, 'Lower_zone_consolidation_score': 0.02547634145839062, 'Miliary_texture_score': 0.8731926528235012, 'Left_right_asymmetry_score': 0.9261141514195511}, 'explanation': 'Terdapat asimetri signifikan antara paru kiri dan kanan, mengarah ke infiltrat unilateral.', 'heatmap_path': '/Users/ahtape/Documents/UGM/CS/semester 3/PCD/TB/tb-detection/detection/temp_mask/Tuberculosis-102_overlay.png'}
